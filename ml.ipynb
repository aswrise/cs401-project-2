# %%
# !pip install mlxtend
from mlxtend.frequent_patterns import apriori,association_rules,fpgrowth
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import numpy as np
# import warnings
# warnings.filterwarnings('ignore')
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
data=pd.read_csv("https://homepages.dcc.ufmg.br/~cunha/hosted/compsci401-s3-23-datasets/playlist-sample-ds1.csv")
data.head()
# Out:
#    pid            name                                   album_name  \
# 0  241  Tegan and Sara  Back In Your Head - The Complete Collection
# 1  241  Tegan and Sara                                   In The Air
# 2  241  Tegan and Sara                                      The Con
# 3  241  Tegan and Sara                                      The Con
# 4  241  Tegan and Sara                                      The Con
#
#       artist_name  duration_ms                             track_name
# 0  Tegan and Sara       425306  Back In Your Head - Morgan Page Remix
# 1     Morgan Page       232426                               Carry Me
# 2  Tegan and Sara        92693                          I Was Married
# 3  Tegan and Sara       180306                      Relief Next To Me
# 4  Tegan and Sara       209266                                The Con

# %%
transactions =[list(i[1]["track_name"]) for i in data.groupby(["name"])]
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df =pd.DataFrame(te_ary,columns=te.columns_)
rules= apriori(df,min_support=0.01,use_colnames=True)
rules["num"]=rules["itemsets"].apply(lambda x:len(x))
rules= association_rules(rules,metric="confidence",min_threshold=0.7)
from datetime import datetime
time=str(datetime.now())
rules=[rules,time]
import pickle
binary_data = pickle.dumps(rules)

# 将序列化的数据保存到文件
with open('rules', 'wb') as f:
    f.write(binary_data)

# 从文件中读取数据并反序列化为 Python 对象
with open('rules', 'rb') as f:
    restored_data = pickle.load(f)

display(restored_data[0])
# Out:
# /tmp/ipykernel_3533534/1367834206.py:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   transactions =[list(i[1]["track_name"]) for i in data.groupby(["name"])]
#                                   antecedents  \
# 0                      (All The Small Things)
# 1                                      (1985)
# 2                                      (1985)
# 3    (Have Yourself a Merry Little Christmas)
# 4           (All I Want for Christmas Is You)
# ..                                        ...
# 121                 (Mask Off, XO TOUR Llif3)
# 122                       (Mask Off, HUMBLE.)
# 123                 (Mask Off, Unforgettable)
# 124            (XO TOUR Llif3, Unforgettable)
# 125                  (HUMBLE., Unforgettable)
#
#                                   consequents  antecedent support  \
# 0                                      (1985)            0.014463
# 1                      (All The Small Things)            0.012397
# 2                    (Sugar  We're Goin Down)            0.012397
# 3           (All I Want for Christmas Is You)            0.012397
# 4    (Have Yourself a Merry Little Christmas)            0.012397
# ..                                        ...                 ...
# 121                  (HUMBLE., Unforgettable)            0.012397
# 122            (XO TOUR Llif3, Unforgettable)            0.012397
# 123                  (XO TOUR Llif3, HUMBLE.)            0.010331
# 124                       (Mask Off, HUMBLE.)            0.010331
# 125                 (Mask Off, XO TOUR Llif3)            0.010331
#
#      consequent support   support  confidence       lift  leverage  conviction
# 0              0.012397  0.010331    0.714286  57.619048  0.010151    3.456612
# 1              0.014463  0.010331    0.833333  57.619048  0.010151    5.913223
# 2              0.022727  0.010331    0.833333  36.666667  0.010049    5.863636
# 3              0.012397  0.010331    0.833333  67.222222  0.010177    5.925620
# 4              0.012397  0.010331    0.833333  67.222222  0.010177    5.925620
# ..                  ...       ...         ...        ...       ...         ...
# 121            0.010331  0.010331    0.833333  80.666667  0.010203    5.938017
# 122            0.010331  0.010331    0.833333  80.666667  0.010203    5.938017
# 123            0.016529  0.010331    1.000000  60.500000  0.010160         inf
# 124            0.012397  0.010331    1.000000  80.666667  0.010203         inf
# 125            0.012397  0.010331    1.000000  80.666667  0.010203         inf
#
# [126 rows x 9 columns]
